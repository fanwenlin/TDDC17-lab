# %% [markdown]
# <a href="https://colab.research.google.com/github/fanwenlin/TDDC17-lab/blob/lab5%2Ffwl/lab5/lab%205a%20-%20MC_TD_SARSA_Qlearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![LiU_logo.png](data:image/png;base64,...)
# ## Linkoping University: TDDC17 Artificial Intelligence
# ---

# %% [markdown]
# **Lab6 : Reinforcement Learning**
#
#
# This lab focuses on understanding the fundamentals of RL, including MDP, and implementing key RL algorithms model-free (on-policy and off-policy). The lab uses [Gym/Gymnasium](https://gymnasium.farama.org/), a standard toolkit for developing and comparing
# RL algorithms in simulated environments.

# %% [markdown]
# ##Install these dependancies

# %%
# !pip install nlopt==2.7.1 numpy spyder==5 pandas matplotlib gymnasium
# Out:
# Requirement already satisfied: nlopt==2.7.1 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: spyder==5 in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: atomicwrites>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (1.4.1)
# Requirement already satisfied: chardet>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (5.2.0)
# Requirement already satisfied: cloudpickle>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (3.1.1)
# Requirement already satisfied: cookiecutter>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (2.6.0)
# Requirement already satisfied: diff-match-patch>=20181111 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (20241021)
# Requirement already satisfied: intervaltree>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (3.1.0)
# Requirement already satisfied: ipython>=7.6.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (7.34.0)
# Requirement already satisfied: jedi==0.17.2 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.17.2)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (4.25.1)
# Requirement already satisfied: keyring>=17.0.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (25.6.0)
# Requirement already satisfied: nbconvert>=4.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (7.16.6)
# Requirement already satisfied: numpydoc>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (1.9.0)
# Requirement already satisfied: parso==0.7.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.7.0)
# Requirement already satisfied: pexpect>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (4.9.0)
# Requirement already satisfied: pickleshare>=0.4 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.7.5)
# Requirement already satisfied: psutil>=5.3 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (5.9.5)
# Requirement already satisfied: pygments>=2.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (2.19.2)
# Requirement already satisfied: pylint>=1.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (3.3.9)
# Requirement already satisfied: pyqt5<5.13 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (5.12.3)
# Requirement already satisfied: pyqtwebengine<5.13 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (5.12.1)
# Requirement already satisfied: python-language-server<1.0.0,>=0.36.2 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (0.36.2)
# Requirement already satisfied: pyls-black>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.4.7)
# Requirement already satisfied: pyls-spyder>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.4.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (26.2.1)
# Requirement already satisfied: qdarkstyle==3.0.2 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (3.0.2)
# Requirement already satisfied: qstylizer>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.2.4)
# Requirement already satisfied: qtawesome>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (1.4.0)
# Requirement already satisfied: qtconsole>=5.0.3 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (5.7.0)
# Requirement already satisfied: qtpy>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (2.4.3)
# Requirement already satisfied: setuptools>=39.0.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (75.2.0)
# Requirement already satisfied: sphinx>=0.6.6 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (8.2.3)
# Requirement already satisfied: spyder-kernels<2.1.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (2.0.5)
# Requirement already satisfied: textdistance>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (4.6.3)
# Requirement already satisfied: three-merge>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.1.1)
# Requirement already satisfied: watchdog<2.0.0,>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (1.0.2)
# Requirement already satisfied: pyxdg>=0.26 in /usr/local/lib/python3.12/dist-packages (from spyder==5) (0.28)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: binaryornot>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (3.1.6)
# Requirement already satisfied: click<9.0.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (8.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (6.0.3)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (2.32.4)
# Requirement already satisfied: arrow in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (1.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from cookiecutter>=1.6.0->spyder==5) (13.9.4)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from intervaltree>=3.0.2->spyder==5) (2.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.6.0->spyder==5) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.6.0->spyder==5) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.6.0->spyder==5) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.6.0->spyder==5) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.6.0->spyder==5) (0.1.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->spyder==5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->spyder==5) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->spyder==5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->spyder==5) (0.27.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=17.0.0->spyder==5) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=17.0.0->spyder==5) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=17.0.0->spyder==5) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=17.0.0->spyder==5) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=17.0.0->spyder==5) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=4.0->spyder==5) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=4.0->spyder==5) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>=4.4.0->spyder==5) (0.7.0)
# Requirement already satisfied: astroid<=3.4.0.dev0,>=3.3.8 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (3.3.11)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (0.3.8)
# Requirement already satisfied: isort!=5.13,<7,>=4.2.5 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (6.1.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (0.6.1)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (4.4.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from pylint>=1.0->spyder==5) (0.13.3)
# Requirement already satisfied: black>=19.3b0 in /usr/local/lib/python3.12/dist-packages (from pyls-black>=0.4.6->spyder==5) (25.9.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from pyls-black>=0.4.6->spyder==5) (0.10.2)
# Requirement already satisfied: python-lsp-server>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pyls-spyder>=0.3.2->spyder==5) (1.13.1)
# Requirement already satisfied: PyQt5_sip<13,>=4.19.14 in /usr/local/lib/python3.12/dist-packages (from pyqt5<5.13->spyder==5) (12.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: python-jsonrpc-server>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server<1.0.0,>=0.36.2->python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (0.4.0)
# Requirement already satisfied: pluggy in /usr/local/lib/python3.12/dist-packages (from python-language-server<1.0.0,>=0.36.2->python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (1.6.0)
# Requirement already satisfied: ujson>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server<1.0.0,>=0.36.2->python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (5.11.0)
# Requirement already satisfied: autopep8 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (1.5.5)
# Requirement already satisfied: flake8>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (3.8.4)
# Requirement already satisfied: pycodestyle<2.7.0,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (2.6.0)
# Requirement already satisfied: pydocstyle>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (6.3.0)
# Requirement already satisfied: pyflakes<2.3.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (2.2.0)
# Requirement already satisfied: rope>=0.10.5 in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (1.14.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/dist-packages (from python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (0.43.0)
# Requirement already satisfied: tinycss2<2,>=0.5 in /usr/local/lib/python3.12/dist-packages (from qstylizer>=0.1.10->spyder==5) (1.4.0)
# Requirement already satisfied: inflection<1,>0.3.0 in /usr/local/lib/python3.12/dist-packages (from qstylizer>=0.1.10->spyder==5) (0.5.1)
# Requirement already satisfied: jupyter_client>=4.1 in /usr/local/lib/python3.12/dist-packages (from qtconsole>=5.0.3->spyder==5) (7.4.9)
# Requirement already satisfied: ipykernel>=4.1 in /usr/local/lib/python3.12/dist-packages (from qtconsole>=5.0.3->spyder==5) (6.17.1)
# Requirement already satisfied: ipython_pygments_lexers in /usr/local/lib/python3.12/dist-packages (from qtconsole>=5.0.3->spyder==5) (1.1.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.0.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=0.6.6->spyder==5) (3.1.0)
# Requirement already satisfied: wurlitzer>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from spyder-kernels<2.1.0,>=2.0.1->spyder==5) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black>=19.3b0->pyls-black>=0.4.6->spyder==5) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from black>=19.3b0->pyls-black>=0.4.6->spyder==5) (0.12.1)
# Requirement already satisfied: pytokens>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from black>=19.3b0->pyls-black>=0.4.6->spyder==5) (0.1.10)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=4.0->spyder==5) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=5.0.3->spyder==5) (1.8.15)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=5.0.3->spyder==5) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.1->qtconsole>=5.0.3->spyder==5) (6.4.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter_client>=4.1->qtconsole>=5.0.3->spyder==5) (0.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert>=4.0->spyder==5) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.6.0->spyder==5) (0.2.14)
# Requirement already satisfied: docstring-to-markdown in /usr/local/lib/python3.12/dist-packages (from python-lsp-server>=1.0.1->pyls-spyder>=0.3.2->spyder==5) (0.17)
# Requirement already satisfied: python-lsp-jsonrpc<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from python-lsp-server>=1.0.1->pyls-spyder>=0.3.2->spyder==5) (1.1.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=4.0.0->cookiecutter>=1.6.0->spyder==5) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder==5) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder==5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder==5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->cookiecutter>=1.6.0->spyder==5) (2025.8.3)
# Requirement already satisfied: pytoolconfig>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from pytoolconfig[global]>=1.2.2->rope>=0.10.5->python-language-server[all]<1.0.0,>=0.36.2->spyder==5) (1.3.1)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=17.0.0->spyder==5) (43.0.3)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow->cookiecutter>=1.6.0->spyder==5) (2.9.0.20250822)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=4.0->spyder==5) (2.8)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=17.0.0->spyder==5) (10.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->cookiecutter>=1.6.0->spyder==5) (4.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=17.0.0->spyder==5) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->cookiecutter>=1.6.0->spyder==5) (0.1.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.12/dist-packages (from docstring-to-markdown->python-lsp-server>=1.0.1->pyls-spyder>=0.3.2->spyder==5) (8.7.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=17.0.0->spyder==5) (2.23)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=3.6->docstring-to-markdown->python-lsp-server>=1.0.1->pyls-spyder>=0.3.2->spyder==5) (3.23.0)

# %% [markdown]
# ##Import libraries

# %%
import matplotlib
# %matplotlib inline
import gymnasium as gym
import sys
import itertools
import numpy as np
import sys
from io import StringIO
from gym import Env, spaces
from gym import spaces
from gym.utils import seeding
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import pandas as pd
from collections import namedtuple
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

EpisodeStats = namedtuple("Stats",["episode_lengths", "episode_rewards"])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
## functions used for plotting
def plot_value_function(V, title="Value Function"):
    """
    Plots the value function as a surface plot.
    """
    min_x = min(k[0] for k in V.keys())
    max_x = max(k[0] for k in V.keys())
    min_y = min(k[1] for k in V.keys())
    max_y = max(k[1] for k in V.keys())

    x_range = np.arange(min_x, max_x + 1)
    y_range = np.arange(min_y, max_y + 1)
    X, Y = np.meshgrid(x_range, y_range)

    # Find value for all (x, y) coordinates
    Z_noace = np.apply_along_axis(lambda _: V[(_[0], _[1], False)], 2, np.dstack([X, Y]))
    Z_ace = np.apply_along_axis(lambda _: V[(_[0], _[1], True)], 2, np.dstack([X, Y]))

    def plot_surface(X, Y, Z, title):
        fig = plt.figure(figsize=(20, 10))
        ax = fig.add_subplot(111, projection='3d')
        surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                               cmap=matplotlib.cm.coolwarm, vmin=-1.0, vmax=1.0)
        ax.set_xlabel('Player Sum')
        ax.set_ylabel('Dealer Showing')
        ax.set_zlabel('Value')
        ax.set_title(title)
        ax.view_init(ax.elev, -120)
        fig.colorbar(surf)
        plt.show()

    plot_surface(X, Y, Z_noace, "{} (No Usable Ace)".format(title))
    plot_surface(X, Y, Z_ace, "{} (Usable Ace)".format(title))



def plot_episode_stats(stats, smoothing_window=10, noshow=False):
    # Plot the episode length over time
    fig1 = plt.figure(figsize=(10,5))
    plt.plot(stats.episode_lengths)
    plt.xlabel("Episode")
    plt.ylabel("Episode Length")
    plt.title("Episode Length over Time")
    if noshow:
        plt.close(fig1)
    else:
        plt.show(fig1)

    # Plot the episode reward over time
    fig2 = plt.figure(figsize=(10,5))
    rewards_smoothed = pd.Series(stats.episode_rewards).rolling(smoothing_window, min_periods=smoothing_window).mean()
    plt.plot(rewards_smoothed)
    plt.xlabel("Episode")
    plt.ylabel("Episode Reward (Smoothed)")
    plt.title("Episode Reward over Time (Smoothed over window size {})".format(smoothing_window))
    if noshow:
        plt.close(fig2)
    else:
        plt.show(fig2)

    # Plot time steps and episode number
    fig3 = plt.figure(figsize=(10,5))
    plt.plot(np.cumsum(stats.episode_lengths), np.arange(len(stats.episode_lengths)))
    plt.xlabel("Time Steps")
    plt.ylabel("Episode")
    plt.title("Episode per time step")
    if noshow:
        plt.close(fig3)
    else:
        plt.show(fig3)

    return fig1, fig2, fig3

# %% [markdown]
# # Part I: Monte Carlo and Temporal Difference Learning
#
# ---
#
# ### Why can't we always rely on Policy / Value Iteration ?
#
# At each state, we look ahead one step at each possible action and next state.
#
# 1.  We can only do this because we have a perfect model of the environment. (the transition matrix $P$). In most applications, this assumption does not hold. We would like an algorithm that can learn from $\mathcal{experience}$, i.e. by simply interacting with the environment
# 2.  DP methods are polynomial in the number of states. Many real world applications have a very large state space, making DP methods unusable

# %% [markdown]
# ## Prediction
# Given a policy $\pi$,  can we find the corresponding value function $v_{\pi}$ ?
#
# Sample episodes of experience and estimate V(s) to be the reward received from that state onwards averaged across all of your experience. The same technique works for the action-value function Q(s, a). Given enough samples, this is proven to converge.
#
# ### MC prediction Algorithm
# **Input**: <br>
# a policy $\pi$ to be evaluated <br>
# the number of episodes for which the run the algorithm, *num_episodes*
#
# **Initialize**:
#
# $ \quad V(s) \in \mathbb{R}$, arbitrarily, for all $s \in S $ <br>
# $ \quad \textit{VisitCount(s)}$, an empty list, for all $s \in S$
#
# **Loop** (for *num_episodes*): <br>
# $ \quad $ Generate an episode following $\pi: S_0,A_0,R_1,S_1,A_1,R_2, ..., S_{T-1},A_{T-1},R_T$ <br>
# $ \quad G \leftarrow 0$ <br>
# $ \quad $ **Loop** for each step of episode, $t = T-1, T-2, ..., 0$: <br>
# $ \quad \quad G \leftarrow \gamma G + R_{t+1} $ <br>
# $ \quad \quad \textit{VisitCount}(S_t) = \textit{VisitCount}(S_t) + 1$ <br>
# $ \quad \quad V(S_t) = V(S_t) + \frac{1}{\textit{VisitCount}(S_t)} (G_t - V(S_t))$
#
# return $V$

# %% [markdown]
# ### Implementation
# We consider the game of blackjack for this exercice, available [here](https://www.gymlibrary.dev/environments/toy_text/blackjack/). I recommend exploring the previous link, to get familiar with the API of the environment.

# %% [markdown]
# #### The BlackJack Environment
# This environment actually builds off the gym interface, so you can interact with it using the same function calls. Here's a quick example

# %%
# create env
env = gym.make('Blackjack-v1', natural=False, sab=False)

print(env.observation_space)
print(gym.__version__)

# reset env
(state, info) = env.reset()

# let's see what's hidden inside this Object
print(vars(env))

# how big is the action space ?
print (f'size of action space {env.action_space.n}')


# let's sample a random action
random_action = env.action_space.sample()



# let's simulate one action
observation, reward, terminated, truncated, info = env.step(random_action)
done = terminated or truncated

print(f'state: {state}')
print(f'observation: {observation}')
print(f'reward: {reward}')
print(f'done: {done}')


# observation : the new state after executing action
# reward      : observed reward after executing action
# done        : `True` if the episode is over, `False` otherwise

# let's reset the environment (do this when `done` == True)
(state, info) = env.reset()
# Out:
# Tuple(Discrete(32), Discrete(11), Discrete(2))
# 1.2.1
# {'_saved_kwargs': {'disable_render_order_enforcing': False}, 'env': <PassiveEnvChecker<BlackjackEnv<Blackjack-v1>>>, '_action_space': None, '_observation_space': None, '_metadata': None, '_cached_spec': None, '_has_reset': True, '_disable_render_order_enforcing': False}
# size of action space 2
# state: (20, 10, 0)
# observation: (20, 10, 0)
# reward: 1.0
# done: True

# %%
def mc_prediction(policy, env, num_episodes, discount_factor=1.0, max_steps_per_episode=100):
    """
    Monte Carlo prediction algorithm. Calculates the value function
    for a given policy using sampling.

    Args:
        policy: A function that maps an observation to action probabilities.
        env: OpenAI gym environment.
        num_episodes: Number of episodes to sample.
        discount_factor: Gamma discount factor.

    Returns:
        A dictionary that maps from state -> value.
        The state is a tuple and the value is a float.
    """

    # Keeps track of sum and count of returns for each state
    returns_sum   = defaultdict(float)
    returns_count = defaultdict(float)

    # The final value function
    V = defaultdict(float)

    for i_episode in range(num_episodes):
        # Print out which episode we're on, useful for debugging.
        if (i_episode+1) % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        # Generate an episode.
        # An episode is an array of (state, action, reward) tuples
        episode = []
        (state, info) = env.reset()
        done = False

        while not done:
            # action = env.action_space.np_random( policy(state) ) #<add code> use the policy
            action = policy(state)  #<add code> use the policy
            next_state, reward, terminated, truncated, info = env.step(action) #<add code> take a step
            done = terminated or truncated

            #<add code> append (state, action, reward) to episode array, it will be used later to update the state value V
            episode += [(state, action, reward)]
            state = next_state

        discounted_return = 0
        for (state, action, reward) in episode[::-1]:
            discounted_return = discounted_return*discount_factor + reward#<add code> calculate the discounted return
            returns_count[state] += 1
            V[state] += 1 / returns_count[state] * (discounted_return - V[state]) #<add code> use the question in the pseudo-code to update V[state]

    return V

# %% [markdown]
# Since we want to do policy evaluation, we'll need a policy. Let's create one

# %%
def sample_policy(observation):
    """
    A policy that sticks if the player score is >= 20 and hits otherwise.
    """
    score, dealer_score, usable_ace = observation
    return 0 if score >= 20 else 1

# %%
env = gym.make('Blackjack-v1')
V_10k = mc_prediction(sample_policy, env, num_episodes=10000)
plot_value_function(V_10k, title="10,000 Steps")
# Out:
# Episode 9999/10000.

# %% [markdown]
# Once your algorithm seems to run correctly, run it longer to see what the real value prediction looks like!

# %%
V_500k = mc_prediction(sample_policy, env, num_episodes=500000)
plot_value_function(V_500k, title="500,000 Steps")
# Out:
# Episode 499999/500000.

# %% [markdown]
# As expected, the more episode you run, the better your estimate gets. This is shown by the plots being much smoother for $t=500000$ vs $t=10000$

# %% [markdown]
# ## Control
# The idea is the same as for Dynamic Programming. Use MC Policy Evaluation to evaluate the current policy then improve the policy greedily. The Problem: How do we ensure that we explore all states if we don't know the full environment?
#
# Solution to exploration problem: Use epsilon-greedy policies instead of full greedy policies. When making a decision act randomly with probability epsilon. This will learn the optimal epsilon-greedy policy.

# %% [markdown]
# ### MC Control Algorithm
# **Input**: <br>
# small $\epsilon > 0$  <br>
# the number of episodes for which the run the algorithm, *num_episodes*
#
# ** Initialize: ** <br>
# $ \quad \pi \leftarrow $ an arbitrary $\epsilon$-soft policy <br>
# $ \quad Q(s,a) \in \mathbb{R}$ (arbitrarily), for all $s \in S, a \in A(s)$ <br>
# $ \quad \textit{VisitCount(s,a)}$, an empty list, for all $s \in S, a \in A(s)$
#
# **Loop** (for *num_episodes*): <br>
# $ \quad $ Generate an episode following $\pi: S_0,A_0,R_1,S_1,A_1,R_2, ..., S_{T-1},A_{T-1},R_T$ <br>
# $ \quad G \leftarrow 0$ <br>
# $ \quad $ **Loop** for each step of episode, $t = T-1, T-2, ..., 0$: <br>
# $ \quad \quad \textit{VisitCount}(S_t, A_t) = \textit{VisitCount}(S_t, A_t) + 1$ <br>
# $ \quad \quad G \leftarrow \gamma G + R_{t+1} $ <br>
# $ \quad \quad Q(S_t, A_t) = Q(S_t, A_t) + \frac{1}{\textit{VisitCount}(S_t, A_t)} (G_t - Q(S_t, A_t))$
#
# $\quad $** Update ** $\pi$ to be $\epsilon$-greedy w.r.t. the update $Q$ values
#
# return $Q, \ \pi$

# %% [markdown]
# ### Implementation
# It's important to break ties arbitrarily when doing control. This is especially important when you initialize all $Q$ or $V$ array to all 0s. If you don't break ties arbitrarily, you will end up always choosing the same action!. Here is a ** argmax ** function that break ties randomly

# %%
def argmax(numpy_array):
    """ argmax implementation that chooses randomly between ties """
    max_indices = np.where(numpy_array == numpy_array.max())[0]
    return max_indices[np.random.randint(max_indices.shape[0])]

# %% [markdown]
# We are also providing you with the following function: Given a $Q$ dictionnary and $\epsilon$, it returns a $\epsilon$-greedy policy. Also, since the argument $Q$ is a python object, the returned $\epsilon$-greedy policy will automatically update as you change the $Q$ values.

# %%
def make_epsilon_greedy_policy(Q, epsilon, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function and epsilon.

    Args:
        Q: A dictionary that maps from state -> action-values.
            Each value is a numpy array of length nA (see below)
        epsilon: The probability to select a random action . float between 0 and 1.
        nA: Number of actions in the environment.

    Returns:
        A function that takes the observation as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.

    """
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        best_action = argmax(Q[observation])
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def mc_control_epsilon_greedy(env, num_episodes, discount_factor=1.0, epsilon=0.1, max_steps_per_episode=100):
    """
    Monte Carlo Control using Epsilon-Greedy policies.
    Finds an optimal epsilon-greedy policy.

    Args:
        env: OpenAI gym environment.
        num_episodes: Number of episodes to sample.
        discount_factor: Gamma discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.

    Returns:
        A tuple (Q, policy).
        Q is a dictionary mapping state -> action values.
        policy is a function that takes an observation as an argument and returns
        action probabilities
    """

    # Keeps track of sum and count of returns for each state
    returns_sum   = defaultdict(float)
    returns_count = defaultdict(float)

    # The final action-value function.
    # A nested dictionary that maps state -> (action -> action-value).
    Q = defaultdict(lambda: np.zeros(env.action_space.n))

    # The policy we're following
    policy = make_epsilon_greedy_policy(Q, epsilon, env.action_space.n) #<add code> call the correct policy

    for i_episode in range(num_episodes):
        # Print out which episode we're on, useful for debugging.
        if (i_episode+1) % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        # Generate an episode.
        # An episode is an array of (state, action, reward) tuples
        episode = []
        (state, info) = env.reset()
        for t in range(max_steps_per_episode):
            probs = policy(state) #<add code> use the policy to get the action probability
            action = np.random.choice(np.arange(len(probs)), p=probs)
            next_state, reward, terminated, truncated, info = env.step(action) #<add code> make a step by executing the action
            episode += [(state, action, reward)]

            if done:
                break

            state = next_state

        discounted_return = 0
        for (state, action, reward) in episode[::-1]:
            discounted_return = discount_factor*discounted_return + reward#<add code> calculate the discounted return
            returns_count[(state, action)] += 1
            Q[state][action] += 1 / returns_count[(state, action)] *(discounted_return - Q[state][action]) #<add code> refer to the pseudo-code to compute the state-action value update Q[state][action]

    return Q, policy

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=500000, epsilon=0.1)
# Out:
# Episode 499999/500000.

# %%
# For plotting: Create value function from action-value function
# by picking the best action at each state
V = defaultdict(float)
for state, actions in Q.items():
    action_value = np.max(actions)
    V[state] = action_value
plot_value_function(V, title="Optimal Value Function")

# %% [markdown]
# ### Comments on MC methods
# So far we have been using the following update rule for MC Control and Prediction
#
# 1) For a given state action pair $(s_t, a_t)$, observe the return $G_t$
#
# 2) Update your estimate in this fashion $V(s_t)$ = $V(s_t) + \frac{1}{VisitCount(s_t)} \bigg[G_t - V(s_t)\bigg] $
#
# It's important to notice that this assings **equal importance to all returns**. In general, this can be problematic when working with nonstationary environments. In this setup, it would be better to *trust/rely more* on newer $Returns$, and rely less on older ones. One easy way to achieve this is by using the following update rule
#
# $$V(s_t) \leftarrow V(s_t) + \alpha \bigg[ G_t - V(s_t) \bigg]$$
#
# This update rule will assign exponentially decresing weights over time. Feel free to (re) implement the above exercises with this update rule. You will not need the returns_count array anymore

# %% [markdown]
# ### Drawbacks of Monte Carlo methods
#
#
# 1.   You need to wait until the end of the episode to perform an update. This can be probablematic if the episode lengths are very long, (or even infinite!)
# 2.   MC methods, while unbiased, tend to have high variance. To see this, note that $$G_t = R_{t+1} + \gamma R_{t+2} + ... + \gamma^{T - t - 1}R_{T}$$ What will be the variance of $G_t$ ? Assuming all the returns are independent*, $$Var(G_t) = Var(R_{t+1}) + \gamma^2 Var(R_{t+2}) + ... + \gamma^{2(T - t - 1)}Var(R_{T})$$
#
# which can become quite large for long episodes.
#
# Ideally, we would like a way to trade off bias for variance. This leads us to the next topic of Temporal Difference Learning.
#
# ---
#
#
# *Independence of returns is not true in general, but the intuition of the variance growing with the size of the episode is still valid

# %% [markdown]
# ### TD  prediction Algorithm
# **Input**: <br>
# a policy $\pi$ to be evaluated <br>
# step size $\alpha \in (0, 1]$ <br>
# the number of episodes for which the run the algorithm, *num_episodes*
#
# **Initialize**:
#
# $ \quad V(s) \in \mathbb{R}$, arbitrarily, for all $s \in S $, except that $V(terminal)=0$ <br>
#
# **Loop** (for *num_episodes*): <br>
# $ \quad $ Initialize $S$ <br>
# $ \quad $ **Loop** for each step of the episode: <br>
# $ \quad \quad A \leftarrow $ action given by $\pi$ for S <br>
# $ \quad \quad $ Take action $A$, observe $R, S'$ <br>
# $ \quad \quad V(S) \leftarrow V(S) + \alpha \big[ R + \gamma V(S') - V(s) \big]$ <br>
# return $V$

# %% [markdown]
# ### TD Control and Q-Learning
# Let's skip prediction for TD methods and go straight to control. Arguably the most famous TD algorithm is Q-Learning, with the following pseudocode.

# %% [markdown]
# ### Q-learning Algorithm
# **Input**: <br>
# step size $\alpha \in (0, 1]$ <br>
# the number of episodes for which the run the algorithm, *num_episodes*
#
# **Initialize**:
#
# $\quad Q(s, a) \in \mathbb{R}$ arbitrarily, for all $s \in S, a \in A(s)$, except that $Q(terminal, \cdot)=0$ <br>
#
# **Loop** (for *num_episodes*): <br>
# $ \quad $ Initialize $S$ <br>
# $ \quad $ **Loop** for each step of the episode: <br>
# $ \quad \quad $ Choose $A$ from $S$ using policy derived from $Q$, (e.g. $\epsilon$-greedy) <br>
# $ \quad \quad $ Take action $A$, observe $R, S'$ <br>
# $ \quad \quad Q(S, A) \leftarrow Q(S, A) + \alpha \big[ R + \gamma \max_a Q(S', a) - Q(s,a) \big]$ <br>
# $ \quad $ until S is terminal
#
# return $Q, \ \pi$

# %% [markdown]
# ### Implementation
# We consider the CliffWorld for this exercice, available [here](https://github.com/dennybritz/reinforcement-learning/blob/master/lib/envs/cliff_walking.py). The API is the same as the other environment, i.e. you can use the same function calls to interact with it.
# ![env](https://i.imgur.com/qz5Kdyf.png)

# %%
env = gym.make('CliffWalking-v1')

# %%
def q_learning(env, num_episodes, discount_factor=1.0, epsilon=0.05, alpha=0.5):
    """
    Q-Learning algorithm: Off-policy TD control. Finds the optimal greedy policy
    while following an epsilon-greedy policy

    Args:
        env: OpenAI environment.
        num_episodes: Number of episodes to run for.
        discount_factor: Gamma discount factor.
        alpha: TD learning rate.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.

    Returns:
        A tuple (Q, episode_lengths).
        Q is the optimal action-value function, a dictionary mapping state -> action values.
        stats is an EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """

    # The final action-value function.
    # A nested dictionary that maps state -> (action -> action-value).
    Q = defaultdict(lambda: np.zeros(env.action_space.n))

    # The policy we're following
    policy = make_epsilon_greedy_policy(Q, epsilon, env.action_space.n) #<add code> call the correct policy

    # Keeps track of useful statistics
    stats = EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))

    for i_episode in range(num_episodes):
        # Print out which episode we're on, useful for debugging.
        if (i_episode +1) % 100 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        # reset environment at the beginning of every episode
        (state, info) = env.reset()

        for t in itertools.count():

            # Take a step (q-l, not sarsa)
            probs = policy(state) #<add code> call the correct policy
            action = np.random.choice(np.arange(len(probs)), p=probs)
            next_state, reward, terminated, truncated, info = env.step(action) #<add code> make a step after executing an action
            done = terminated or truncated

            # Update statistics
            stats.episode_rewards[i_episode] += reward
            stats.episode_lengths[i_episode] = t

            # TD update
            best_next_action = np.argmax(Q[next_state]) #<add code> compute the best action

            # NOTE: would this line still if `next_state` is terminal AND Q is NOt initialized to all 0's ?
            td_target = reward + discount_factor*Q[next_state][best_next_action] if not terminated else reward #<add code> compute the td target based on the pseudo-code
            td_delta = td_target - Q[state][action] #<add code> compute the td error
            Q[state][action] += alpha * td_delta#<add code> then update the state-action value

            if done:
                break

            state = next_state


    return Q, stats

# %%
Q, stats_q_learning = q_learning(env, num_episodes=500)
plot_episode_stats(stats_q_learning)
# Out:
# Episode 499/500.
# (<Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>)

# %% [markdown]
# ### SARSA
# Q-learning is an offline method, since the target update does not depend on the behavior policy (because of the max operator). The online version of Q-Learning is known as SARSA (which stands for State, Action, Reward, State, Action). Notice that in the following pseudocode, the action selected in the target update is the same as the action used in the next timestep

# %% [markdown]
# ### SARSA Algorithm
# **Input**: <br>
# step size $\alpha \in (0, 1]$ <br>
# the number of episodes for which the run the algorithm, *num_episodes*
#
# **Initialize**:
#
# $\quad Q(s, a) \in \mathbb{R}$ arbitrarily, for all $s \in S, a \in A(s)$, except that $Q(terminal, \cdot)=0$ <br>
#
# **Loop** (for *num_episodes*): <br>
# $ \quad $ Initialize $S$ <br>
# $ \quad $ Choose $A$ from $S$ using policy derived from $Q$, (e.g. $\epsilon$-greedy) <br>
# $ \quad $ **Loop** for each step of the episode: <br>
# $ \quad \quad $ Take action $A$, observe $R, S'$ <br>
# $ \quad \quad $ Choose $A'$ from $S'$ using policy derived from $Q$, (e.g. $\epsilon$-greedy) <br>
# $ \quad \quad Q(S, A) \leftarrow Q(S, A) + \alpha \big[ R + \gamma Q(S', A') - Q(s,a) \big]$ <br>
# $ \quad $ until S is terminal
#
# return $Q, \ \pi$

# %%
def SARSA(env, num_episodes, discount_factor=1.0, epsilon=0.1, alpha=0.5):
    """
    SARSA algorithm: On-policy TD control. Finds the optimal greedy policy
    while following an epsilon-greedy policy

    Args:
        env: OpenAI environment.
        num_episodes: Number of episodes to run for.
        discount_factor: Gamma discount factor.
        alpha: TD learning rate.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.

    Returns:
        A tuple (Q, episode_lengths).
        Q is the optimal action-value function, a dictionary mapping state -> action values.
        stats is an EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """

    # The final action-value function.
    # A nested dictionary that maps state -> (action -> action-value).
    Q = defaultdict(lambda: np.zeros(env.action_space.n))

    # The policy we're following
    policy = make_epsilon_greedy_policy(Q, epsilon, env.action_space.n) #<add code> call the correct policy

    # Keeps track of useful statistics
    stats = EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))

    for i_episode in range(num_episodes):
        # Print out which episode we're on, useful for debugging.
        if (i_episode +1) % 100 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()

        # reset environment at the beginning of every episode
        (state, info) = env.reset()
        probs = policy(state)
        action = np.random.choice(np.arange(len(probs)), p=probs)

        for t in itertools.count():

            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            # Update statistics
            stats.episode_rewards[i_episode] += reward
            stats.episode_lengths[i_episode] = t

            # TD update
            next_action_probs = policy(next_state)
            next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)

            # NOTE: would this line still if `next_state` is terminal AND Q is NOt initialized to all 0's ?
            td_target = reward + discount_factor*Q[next_state] #<add code> comute the td target
            td_delta = reward + discount_factor*Q[next_state][next_action] if not terminated else reward #<add code> compute the td error
            Q[state][action] += alpha * td_delta #<add code> update the state-action value

            if done:
                break

            state  = next_state
            action = next_action

    return Q, stats

# %%
Q, stats_q_learning = SARSA(env, num_episodes=500)
plot_episode_stats(stats_q_learning)
# Out:
# Episode 499/500.
# (<Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>,
#  <Figure size 1000x500 with 1 Axes>)
